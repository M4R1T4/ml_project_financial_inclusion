# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import model_functions as mf

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
plot_colors = ['Cornflowerblue','#C43714','gold','#076B00','#8368CC','darkorange', 'navy', 'lightskyblue','#DA3287', '#FFFF31']
sns.set_palette(plot_colors)

# %%
df = pd.read_csv('../data/data_bank_account.csv')
print('data frame shape :', df.shape)
df.head()
# Out:
# data frame shape : (23524, 13)
#   country  year    uniqueid bank_account location_type cellphone_access
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes  \
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent
# 0               3                 24               Female  \
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status
# 0                 Spouse  Married/Living together  \
# 1      Head of Household                  Widowed
# 2         Other relative     Single/Never Married
# 3      Head of Household  Married/Living together
# 4                  Child     Single/Never Married
#
#                    education_level                   job_type
# 0              Secondary education              Self employed
# 1              No formal education       Government Dependent
# 2  Vocational/Specialised training              Self employed
# 3                Primary education  Formally employed Private
# 4                Primary education        Informally employed

# %%
# drop columns I don't need for my model
df.drop('year', axis=1, inplace=True)
df.drop('uniqueid', axis=1, inplace=True)
df.head()
# Out:
#   country bank_account location_type cellphone_access  household_size
# 0   Kenya          Yes         Rural              Yes               3  \
# 1   Kenya           No         Rural               No               5
# 2   Kenya          Yes         Urban              Yes               5
# 3   Kenya           No         Rural              Yes               5
# 4   Kenya           No         Urban               No               8
#
#    age_of_respondent gender_of_respondent relationship_with_head
# 0                 24               Female                 Spouse  \
# 1                 70               Female      Head of Household
# 2                 26                 Male         Other relative
# 3                 34               Female      Head of Household
# 4                 26                 Male                  Child
#
#             marital_status                  education_level
# 0  Married/Living together              Secondary education  \
# 1                  Widowed              No formal education
# 2     Single/Never Married  Vocational/Specialised training
# 3  Married/Living together                Primary education
# 4     Single/Never Married                Primary education
#
#                     job_type
# 0              Self employed
# 1       Government Dependent
# 2              Self employed
# 3  Formally employed Private
# 4        Informally employed

# %%
df.columns
# Out:
# Index(['country', 'bank_account', 'location_type', 'cellphone_access',
#        'household_size', 'age_of_respondent', 'gender_of_respondent',
#        'relationship_with_head', 'marital_status', 'education_level',
#        'job_type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   bank_account            23524 non-null  object
#  2   location_type           23524 non-null  object
#  3   cellphone_access        23524 non-null  object
#  4   household_size          23524 non-null  int64
#  5   age_of_respondent       23524 non-null  int64
#  6   gender_of_respondent    23524 non-null  object
#  7   relationship_with_head  23524 non-null  object
#  8   marital_status          23524 non-null  object
#  9   education_level         23524 non-null  object
#  10  job_type                23524 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 2.0+ MB

# %% [markdown]
# Convert categorical features

# %%
# categorical features
cat_features = ['country', 'bank_account', 'location_type',
                    'cellphone_access', 'gender_of_respondent',
                    'relationship_with_head', 'marital_status',
                    'education_level', 'job_type']

# %%
for item in cat_features:
    print(item, len(df[item].unique()), df[item].unique())
# Out:
# country 4 ['Kenya' 'Rwanda' 'Tanzania' 'Uganda']
# bank_account 2 ['Yes' 'No']
# location_type 2 ['Rural' 'Urban']
# cellphone_access 2 ['Yes' 'No']
# gender_of_respondent 2 ['Female' 'Male']
# relationship_with_head 6 ['Spouse' 'Head of Household' 'Other relative' 'Child' 'Parent'
#  'Other non-relatives']
# marital_status 5 ['Married/Living together' 'Widowed' 'Single/Never Married'
#  'Divorced/Seperated' 'Dont know']
# education_level 6 ['Secondary education' 'No formal education'
#  'Vocational/Specialised training' 'Primary education'
#  'Tertiary education' 'Other/Dont know/RTA']
# job_type 10 ['Self employed' 'Government Dependent' 'Formally employed Private'
#  'Informally employed' 'Formally employed Government'
#  'Farming and Fishing' 'Remittance Dependent' 'Other Income'
#  'Dont Know/Refuse to answer' 'No Income']

# %%
df['bank_account'] = df['bank_account'].map({'No': 0, 'Yes': 1})
df['location_type'] = df['location_type'].map({'Rural': 0, 'Urban': 1})
df.columns = df.columns.str.replace('location_type','Urban_location')
df['cellphone_access'] = df['cellphone_access'].map({'No': 0, 'Yes': 1})
df['gender_of_respondent'] = df['gender_of_respondent'].map({'Male': 0, 'Female': 1})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   bank_account            23524 non-null  int64
#  2   Urban_location          23524 non-null  int64
#  3   cellphone_access        23524 non-null  int64
#  4   household_size          23524 non-null  int64
#  5   age_of_respondent       23524 non-null  int64
#  6   gender_of_respondent    23524 non-null  int64
#  7   relationship_with_head  23524 non-null  object
#  8   marital_status          23524 non-null  object
#  9   education_level         23524 non-null  object
#  10  job_type                23524 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
# get dummies for categorical values
df = pd.get_dummies(df, columns=['country',
                    'relationship_with_head', 'marital_status',
                    'education_level', 'job_type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 37 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   bank_account                                     23524 non-null  int64
#  1   Urban_location                                   23524 non-null  int64
#  2   cellphone_access                                 23524 non-null  int64
#  3   household_size                                   23524 non-null  int64
#  4   age_of_respondent                                23524 non-null  int64
#  5   gender_of_respondent                             23524 non-null  int64
#  6   country_Kenya                                    23524 non-null  bool
#  7   country_Rwanda                                   23524 non-null  bool
#  8   country_Tanzania                                 23524 non-null  bool
#  9   country_Uganda                                   23524 non-null  bool
#  10  relationship_with_head_Child                     23524 non-null  bool
#  11  relationship_with_head_Head of Household         23524 non-null  bool
#  12  relationship_with_head_Other non-relatives       23524 non-null  bool
#  13  relationship_with_head_Other relative            23524 non-null  bool
#  14  relationship_with_head_Parent                    23524 non-null  bool
#  15  relationship_with_head_Spouse                    23524 non-null  bool
#  16  marital_status_Divorced/Seperated                23524 non-null  bool
#  17  marital_status_Dont know                         23524 non-null  bool
#  18  marital_status_Married/Living together           23524 non-null  bool
#  19  marital_status_Single/Never Married              23524 non-null  bool
#  20  marital_status_Widowed                           23524 non-null  bool
#  21  education_level_No formal education              23524 non-null  bool
#  22  education_level_Other/Dont know/RTA              23524 non-null  bool
#  23  education_level_Primary education                23524 non-null  bool
#  24  education_level_Secondary education              23524 non-null  bool
#  25  education_level_Tertiary education               23524 non-null  bool
#  26  education_level_Vocational/Specialised training  23524 non-null  bool
#  27  job_type_Dont Know/Refuse to answer              23524 non-null  bool
#  28  job_type_Farming and Fishing                     23524 non-null  bool
#  29  job_type_Formally employed Government            23524 non-null  bool
#  30  job_type_Formally employed Private               23524 non-null  bool
#  31  job_type_Government Dependent                    23524 non-null  bool
#  32  job_type_Informally employed                     23524 non-null  bool
#  33  job_type_No Income                               23524 non-null  bool
#  34  job_type_Other Income                            23524 non-null  bool
#  35  job_type_Remittance Dependent                    23524 non-null  bool
#  36  job_type_Self employed                           23524 non-null  bool
# dtypes: bool(31), int64(6)
# memory usage: 1.8 MB

# %%
cat_features = ['bank_account','Urban_location', 'cellphone_access', 'gender_of_respondent', 'country_Kenya',
       'country_Rwanda', 'country_Tanzania', 'country_Uganda',
       'relationship_with_head_Child',
       'relationship_with_head_Head of Household',
       'relationship_with_head_Other non-relatives',
       'relationship_with_head_Other relative',
       'relationship_with_head_Parent', 'relationship_with_head_Spouse',
       'marital_status_Divorced/Seperated', 'marital_status_Dont know',
       'marital_status_Married/Living together',
       'marital_status_Single/Never Married', 'marital_status_Widowed',
       'education_level_No formal education',
       'education_level_Other/Dont know/RTA',
       'education_level_Primary education',
       'education_level_Secondary education',
       'education_level_Tertiary education',
       'education_level_Vocational/Specialised training',
       'job_type_Dont Know/Refuse to answer', 'job_type_Farming and Fishing',
       'job_type_Formally employed Government',
       'job_type_Formally employed Private', 'job_type_Government Dependent',
       'job_type_Informally employed', 'job_type_No Income',
       'job_type_Other Income', 'job_type_Remittance Dependent',
       'job_type_Self employed']
df[cat_features] = df[cat_features].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 37 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   bank_account                                     23524 non-null  category
#  1   Urban_location                                   23524 non-null  category
#  2   cellphone_access                                 23524 non-null  category
#  3   household_size                                   23524 non-null  int64
#  4   age_of_respondent                                23524 non-null  int64
#  5   gender_of_respondent                             23524 non-null  category
#  6   country_Kenya                                    23524 non-null  category
#  7   country_Rwanda                                   23524 non-null  category
#  8   country_Tanzania                                 23524 non-null  category
#  9   country_Uganda                                   23524 non-null  category
#  10  relationship_with_head_Child                     23524 non-null  category
#  11  relationship_with_head_Head of Household         23524 non-null  category
#  12  relationship_with_head_Other non-relatives       23524 non-null  category
#  13  relationship_with_head_Other relative            23524 non-null  category
#  14  relationship_with_head_Parent                    23524 non-null  category
#  15  relationship_with_head_Spouse                    23524 non-null  category
#  16  marital_status_Divorced/Seperated                23524 non-null  category
#  17  marital_status_Dont know                         23524 non-null  category
#  18  marital_status_Married/Living together           23524 non-null  category
#  19  marital_status_Single/Never Married              23524 non-null  category
#  20  marital_status_Widowed                           23524 non-null  category
#  21  education_level_No formal education              23524 non-null  category
#  22  education_level_Other/Dont know/RTA              23524 non-null  category
#  23  education_level_Primary education                23524 non-null  category
#  24  education_level_Secondary education              23524 non-null  category
#  25  education_level_Tertiary education               23524 non-null  category
#  26  education_level_Vocational/Specialised training  23524 non-null  category
#  27  job_type_Dont Know/Refuse to answer              23524 non-null  category
#  28  job_type_Farming and Fishing                     23524 non-null  category
#  29  job_type_Formally employed Government            23524 non-null  category
#  30  job_type_Formally employed Private               23524 non-null  category
#  31  job_type_Government Dependent                    23524 non-null  category
#  32  job_type_Informally employed                     23524 non-null  category
#  33  job_type_No Income                               23524 non-null  category
#  34  job_type_Other Income                            23524 non-null  category
#  35  job_type_Remittance Dependent                    23524 non-null  category
#  36  job_type_Self employed                           23524 non-null  category
# dtypes: category(35), int64(2)
# memory usage: 1.1 MB

# %% [markdown]
# Train-Test-Split and scaling with standartscaler

# %%
selected_features = ['Urban_location', 'cellphone_access', 'household_size',
       'age_of_respondent', 'gender_of_respondent', 'country_Kenya',
       'country_Rwanda', 'country_Tanzania', 'country_Uganda',
       'relationship_with_head_Child',
       'relationship_with_head_Head of Household',
       'relationship_with_head_Other non-relatives',
       'relationship_with_head_Other relative',
       'relationship_with_head_Parent', 'relationship_with_head_Spouse',
       'marital_status_Divorced/Seperated', 'marital_status_Dont know',
       'marital_status_Married/Living together',
       'marital_status_Single/Never Married', 'marital_status_Widowed',
       'education_level_No formal education',
       'education_level_Other/Dont know/RTA',
       'education_level_Primary education',
       'education_level_Secondary education',
       'education_level_Tertiary education',
       'education_level_Vocational/Specialised training',
       'job_type_Dont Know/Refuse to answer', 'job_type_Farming and Fishing',
       'job_type_Formally employed Government',
       'job_type_Formally employed Private', 'job_type_Government Dependent',
       'job_type_Informally employed', 'job_type_No Income',
       'job_type_Other Income', 'job_type_Remittance Dependent',
       'job_type_Self employed']

# %%
X = df[selected_features]
y = df['bank_account']

# %%
# Train-Test-Split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=123,
                                                    stratify=y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (16466, 36)
# (7058, 36)
# (16466,)
# (7058,)

# %% [markdown]
# scaling of the features houselhold_size and age_of_respondent

# %%
X_train_2_sc = X_train[['household_size','age_of_respondent']]
X_test_2_sc = X_test[['household_size','age_of_respondent']]

# %%
# Scaling with MinMaxScaler
normalizer = MinMaxScaler()
X_train_sc = normalizer.fit_transform(X_train_2_sc)
X_test_sc = normalizer.transform(X_test_2_sc)

# %% [markdown]
# add the scaled features back to the dataframe

# %%
# Concatenating scaled and dummy columns 
X_train_prepro = np.concatenate([X_train_sc, X_train.drop(['household_size','age_of_respondent'], axis=1)], axis=1)
X_test_prepro = np.concatenate([X_test_sc, X_test.drop(['household_size','age_of_respondent'], axis=1)], axis=1)

# %%
X_train
# Out:
#       Urban_location cellphone_access  household_size  age_of_respondent
# 6345               1                1               5                 28  \
# 17322              1                1               3                 63
# 22904              0                0               1                 65
# 13745              0                1               7                 18
# 19371              1                0               1                 70
# ...              ...              ...             ...                ...
# 23331              0                1               3                 26
# 18130              1                1               3                 46
# 20442              0                1               5                 70
# 17678              1                0               1                 43
# 16242              1                1               2                 24
#
#       gender_of_respondent country_Kenya country_Rwanda country_Tanzania
# 6345                     0         False           True            False  \
# 17322                    0         False          False             True
# 22904                    1         False          False            False
# 13745                    0         False           True            False
# 19371                    1         False          False             True
# ...                    ...           ...            ...              ...
# 23331                    1         False          False            False
# 18130                    1         False          False             True
# 20442                    0         False          False             True
# 17678                    1         False          False             True
# 16242                    1         False          False             True
#
#       country_Uganda relationship_with_head_Child  ...
# 6345           False                        False  ...  \
# 17322          False                        False  ...
# 22904           True                        False  ...
# 13745          False                        False  ...
# 19371          False                        False  ...
# ...              ...                          ...  ...
# 23331           True                        False  ...
# 18130          False                        False  ...
# 20442          False                        False  ...
# 17678          False                        False  ...
# 16242          False                        False  ...
#
#       job_type_Dont Know/Refuse to answer job_type_Farming and Fishing
# 6345                                False                        False  \
# 17322                               False                        False
# 22904                               False                        False
# 13745                               False                         True
# 19371                               False                        False
# ...                                   ...                          ...
# 23331                               False                        False
# 18130                               False                        False
# 20442                               False                        False
# 17678                               False                        False
# 16242                               False                        False
#
#       job_type_Formally employed Government
# 6345                                  False  \
# 17322                                 False
# 22904                                 False
# 13745                                 False
# 19371                                 False
# ...                                     ...
# 23331                                 False
# 18130                                 False
# 20442                                 False
# 17678                                 False
# 16242                                 False
#
#       job_type_Formally employed Private job_type_Government Dependent
# 6345                               False                         False  \
# 17322                              False                         False
# 22904                              False                         False
# 13745                              False                         False
# 19371                              False                         False
# ...                                  ...                           ...
# 23331                              False                         False
# 18130                              False                         False
# 20442                               True                         False
# 17678                              False                         False
# 16242                              False                         False
#
#       job_type_Informally employed job_type_No Income job_type_Other Income
# 6345                         False              False                 False  \
# 17322                        False              False                 False
# 22904                        False              False                 False
# 13745                        False              False                 False
# 19371                        False              False                 False
# ...                            ...                ...                   ...
# 23331                        False              False                  True
# 18130                        False              False                 False
# 20442                        False              False                 False
# 17678                        False              False                 False
# 16242                        False              False                 False
#
#       job_type_Remittance Dependent job_type_Self employed
# 6345                          False                   True
# 17322                         False                   True
# 22904                         False                   True
# 13745                         False                  False
# 19371                         False                   True
# ...                             ...                    ...
# 23331                         False                  False
# 18130                         False                   True
# 20442                         False                  False
# 17678                         False                   True
# 16242                         False                   True
#
# [16466 rows x 36 columns]

# %% [markdown]
# KNN Models with different parameters

# %%
knn_error_lst = []
for metr in range(1,4):
    for neigh in np.arange(5,55,5): 
        knn_model = mf.train_model(KNeighborsClassifier,
                           X_train_prepro,
                           y_train,
                           n_neighbors=neigh,
                           p=metr,
                           weights='uniform')
        
        loop_name =  'knn_metr_' + str(metr) + '_neigh_' + str(neigh)
        #knn_metrics_dict = mf.model_scores_df(knn_model, X_train, X_test, y_train, y_test , loop_name)
        knn_error_lst.append(mf.model_scores_df(knn_model, X_train_prepro, X_test_prepro, y_train, y_test , loop_name))
        
knn_error_df = pd.DataFrame(knn_error_lst)
knn_error_df['delta_gmean'] = abs(knn_error_df['train_gmean'] - knn_error_df['test_gmean'])
knn_error_df
# Out:
#              model_name  train_accuracy  test_accuracy  train_gmean
# 0    knn_metr_1_neigh_5            0.90           0.88         0.68  \
# 1   knn_metr_1_neigh_10            0.90           0.88         0.60
# 2   knn_metr_1_neigh_15            0.89           0.88         0.60
# 3   knn_metr_1_neigh_20            0.89           0.88         0.57
# 4   knn_metr_1_neigh_25            0.89           0.88         0.59
# 5   knn_metr_1_neigh_30            0.89           0.88         0.56
# 6   knn_metr_1_neigh_35            0.89           0.88         0.56
# 7   knn_metr_1_neigh_40            0.89           0.88         0.54
# 8   knn_metr_1_neigh_45            0.89           0.88         0.55
# 9   knn_metr_1_neigh_50            0.89           0.88         0.54
# 10   knn_metr_2_neigh_5            0.91           0.88         0.68
# 11  knn_metr_2_neigh_10            0.90           0.88         0.60
# 12  knn_metr_2_neigh_15            0.89           0.88         0.60
# 13  knn_metr_2_neigh_20            0.89           0.88         0.57
# 14  knn_metr_2_neigh_25            0.89           0.88         0.58
# 15  knn_metr_2_neigh_30            0.89           0.88         0.56
# 16  knn_metr_2_neigh_35            0.89           0.88         0.56
# 17  knn_metr_2_neigh_40            0.89           0.88         0.54
# 18  knn_metr_2_neigh_45            0.89           0.88         0.55
# 19  knn_metr_2_neigh_50            0.89           0.88         0.54
# 20   knn_metr_3_neigh_5            0.91           0.88         0.68
# 21  knn_metr_3_neigh_10            0.90           0.88         0.60
# 22  knn_metr_3_neigh_15            0.89           0.88         0.60
# 23  knn_metr_3_neigh_20            0.89           0.88         0.57
# 24  knn_metr_3_neigh_25            0.89           0.88         0.58
# 25  knn_metr_3_neigh_30            0.89           0.88         0.56
# 26  knn_metr_3_neigh_35            0.89           0.88         0.56
# 27  knn_metr_3_neigh_40            0.89           0.88         0.54
# 28  knn_metr_3_neigh_45            0.89           0.88         0.55
# 29  knn_metr_3_neigh_50            0.89           0.88         0.54
#
#     test_gmean  train_sensitivity  test_sensitivity  train_specificity
# 0         0.59               0.47              0.37               0.98  \
# 1         0.56               0.36              0.32               0.98
# 2         0.57               0.37              0.34               0.98
# 3         0.54               0.33              0.30               0.98
# 4         0.56               0.36              0.32               0.98
# 5         0.53               0.32              0.29               0.98
# 6         0.54               0.32              0.30               0.98
# 7         0.53               0.30              0.28               0.98
# 8         0.54               0.30              0.29               0.98
# 9         0.52               0.29              0.28               0.98
# 10        0.59               0.48              0.37               0.98
# 11        0.57               0.37              0.33               0.98
# 12        0.57               0.37              0.34               0.98
# 13        0.55               0.34              0.31               0.98
# 14        0.56               0.35              0.32               0.98
# 15        0.54               0.32              0.30               0.98
# 16        0.54               0.32              0.30               0.98
# 17        0.53               0.30              0.28               0.98
# 18        0.53               0.30              0.29               0.98
# 19        0.52               0.29              0.28               0.98
# 20        0.60               0.48              0.37               0.98
# 21        0.57               0.36              0.33               0.98
# 22        0.57               0.37              0.34               0.98
# 23        0.54               0.33              0.30               0.98
# 24        0.56               0.35              0.32               0.98
# 25        0.54               0.32              0.29               0.98
# 26        0.54               0.32              0.30               0.98
# 27        0.53               0.30              0.28               0.98
# 28        0.53               0.30              0.29               0.98
# 29        0.52               0.29              0.28               0.98
#
#     test_specificity  delta_gmean
# 0               0.96         0.09
# 1               0.97         0.04
# 2               0.97         0.03
# 3               0.98         0.03
# 4               0.97         0.03
# 5               0.98         0.03
# 6               0.98         0.02
# 7               0.98         0.01
# 8               0.98         0.01
# 9               0.98         0.02
# 10              0.96         0.09
# 11              0.97         0.03
# 12              0.97         0.03
# 13              0.98         0.02
# 14              0.97         0.02
# 15              0.98         0.02
# 16              0.98         0.02
# 17              0.98         0.01
# 18              0.98         0.02
# 19              0.98         0.02
# 20              0.96         0.08
# 21              0.97         0.03
# 22              0.97         0.03
# 23              0.98         0.03
# 24              0.97         0.02
# 25              0.98         0.02
# 26              0.98         0.02
# 27              0.98         0.01
# 28              0.98         0.02
# 29              0.98         0.02

# %%
knn_error_df.sort_values(by = ['test_gmean', 'delta_gmean'], ascending=[False, True]).head(7)
# Out:
#              model_name  train_accuracy  test_accuracy  train_gmean
# 20   knn_metr_3_neigh_5            0.91           0.88         0.68  \
# 0    knn_metr_1_neigh_5            0.90           0.88         0.68
# 10   knn_metr_2_neigh_5            0.91           0.88         0.68
# 2   knn_metr_1_neigh_15            0.89           0.88         0.60
# 11  knn_metr_2_neigh_10            0.90           0.88         0.60
# 12  knn_metr_2_neigh_15            0.89           0.88         0.60
# 21  knn_metr_3_neigh_10            0.90           0.88         0.60
#
#     test_gmean  train_sensitivity  test_sensitivity  train_specificity
# 20        0.60               0.48              0.37               0.98  \
# 0         0.59               0.47              0.37               0.98
# 10        0.59               0.48              0.37               0.98
# 2         0.57               0.37              0.34               0.98
# 11        0.57               0.37              0.33               0.98
# 12        0.57               0.37              0.34               0.98
# 21        0.57               0.36              0.33               0.98
#
#     test_specificity  delta_gmean
# 20              0.96         0.08
# 0               0.96         0.09
# 10              0.96         0.09
# 2               0.97         0.03
# 11              0.97         0.03
# 12              0.97         0.03
# 21              0.97         0.03

# %%
mf.metrics_comp_scatterplot(knn_error_df)
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/ml_project_financial_inclusion/models/model_functions.py:214: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %% [markdown]
# Specificity is relatively unaffected by the different algorithm parameters. The Majority Class is always predicted similarly well. The situation is different for the sensitivity representing the minority class. Changing the parameters has a high influence on the prediction of this class.
# For Sensitivity and gmean the range up to 26  looks interesting. I will break this down even more finely.
# (Later the range was reduced to 8-16, I can always adjust the loop)

# %%
knn_error_lst = []
for metr in range(1,4):
    for neigh in np.arange(8,21,2): 
        knn_model = mf.train_model(KNeighborsClassifier,
                           X_train_prepro,
                           y_train,
                           n_neighbors=neigh,
                           p=metr,
                           weights='uniform')
        
        loop_name =  'knn_metr_' + str(metr) + '_neigh_' + str(neigh)
        #knn_metrics_dict = mf.model_scores_df(knn_model, X_train, X_test, y_train, y_test , loop_name)
        knn_error_lst.append(mf.model_scores_df(knn_model, X_train_prepro, X_test_prepro, y_train, y_test , loop_name))
        
knn_error_df = pd.DataFrame(knn_error_lst)
knn_error_df['delta_gmean'] = abs(knn_error_df['train_gmean'] - knn_error_df['test_gmean'])
knn_error_df.sort_values(by = ['test_gmean', 'delta_gmean'], ascending=[False, True])
# Out:
#              model_name  train_accuracy  test_accuracy  train_gmean
# 2   knn_metr_1_neigh_12            0.89           0.88         0.59  \
# 0    knn_metr_1_neigh_8            0.90           0.88         0.60
# 7    knn_metr_2_neigh_8            0.90           0.88         0.60
# 8   knn_metr_2_neigh_10            0.90           0.88         0.60
# 14   knn_metr_3_neigh_8            0.90           0.88         0.60
# 15  knn_metr_3_neigh_10            0.90           0.88         0.60
# 3   knn_metr_1_neigh_14            0.89           0.88         0.58
# 10  knn_metr_2_neigh_14            0.89           0.88         0.58
# 17  knn_metr_3_neigh_14            0.89           0.88         0.58
# 9   knn_metr_2_neigh_12            0.89           0.88         0.59
# 16  knn_metr_3_neigh_12            0.89           0.88         0.59
# 1   knn_metr_1_neigh_10            0.90           0.88         0.60
# 11  knn_metr_2_neigh_16            0.89           0.88         0.57
# 13  knn_metr_2_neigh_20            0.89           0.88         0.57
# 18  knn_metr_3_neigh_16            0.89           0.88         0.57
# 4   knn_metr_1_neigh_16            0.89           0.88         0.58
# 5   knn_metr_1_neigh_18            0.89           0.88         0.58
# 12  knn_metr_2_neigh_18            0.89           0.88         0.58
# 19  knn_metr_3_neigh_18            0.89           0.88         0.58
# 6   knn_metr_1_neigh_20            0.89           0.88         0.57
# 20  knn_metr_3_neigh_20            0.89           0.88         0.57
#
#     test_gmean  train_sensitivity  test_sensitivity  train_specificity
# 2         0.57               0.35              0.33               0.98  \
# 0         0.57               0.36              0.33               0.98
# 7         0.57               0.37              0.33               0.98
# 8         0.57               0.37              0.33               0.98
# 14        0.57               0.37              0.33               0.98
# 15        0.57               0.36              0.33               0.98
# 3         0.56               0.34              0.32               0.98
# 10        0.56               0.34              0.32               0.98
# 17        0.56               0.34              0.32               0.98
# 9         0.56               0.35              0.32               0.98
# 16        0.56               0.36              0.32               0.98
# 1         0.56               0.36              0.32               0.98
# 11        0.55               0.33              0.31               0.98
# 13        0.55               0.34              0.31               0.98
# 18        0.55               0.34              0.31               0.98
# 4         0.55               0.34              0.31               0.98
# 5         0.55               0.34              0.31               0.98
# 12        0.55               0.34              0.31               0.98
# 19        0.55               0.34              0.31               0.98
# 6         0.54               0.33              0.30               0.98
# 20        0.54               0.33              0.30               0.98
#
#     test_specificity  delta_gmean
# 2               0.98         0.02
# 0               0.97         0.03
# 7               0.98         0.03
# 8               0.97         0.03
# 14              0.98         0.03
# 15              0.97         0.03
# 3               0.98         0.02
# 10              0.98         0.02
# 17              0.98         0.02
# 9               0.97         0.03
# 16              0.97         0.03
# 1               0.97         0.04
# 11              0.98         0.02
# 13              0.98         0.02
# 18              0.98         0.02
# 4               0.98         0.03
# 5               0.98         0.03
# 12              0.98         0.03
# 19              0.97         0.03
# 6               0.98         0.03
# 20              0.98         0.03

# %%
mf.metrics_comp_scatterplot(knn_error_df)
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/ml_project_financial_inclusion/models/model_functions.py:214: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %% [markdown]
# From these I would choose manhattan distance (p=1) and neighbours = 12 as the most optimal combination.

# %%
knn_model_p1_n12 = mf.train_model(KNeighborsClassifier,
                           X_train_prepro,
                           y_train,
                           n_neighbors=12,
                           p=1,
                           weights='uniform')

# %%
knn_p1_n12_dict = mf.model_scores_df(knn_model_p1_n12, X_train_prepro, X_test_prepro, y_train, y_test , 'KNN_p1_n12')
knn_p1_n12_dict
# Out:
# {'model_name': 'KNN_p1_n12',
#  'train_accuracy': 0.89,
#  'test_accuracy': 0.88,
#  'train_gmean': 0.59,
#  'test_gmean': 0.57,
#  'train_sensitivity': 0.35,
#  'test_sensitivity': 0.33,
#  'train_specificity': 0.98,
#  'test_specificity': 0.98}

# %%
knn_p1_n12_cmx = confusion_matrix(y_test, knn_model_p1_n12.predict(X_test_prepro))
knn_p1_n12_cmx
# Out:
# array([[5917,  147],
#        [ 667,  327]])

# %%
mf.conf_matrix_heatmap_perc(knn_p1_n12_cmx)

# %%
mf.metrics_line_scatterplot(knn_p1_n12_dict)
plt.savefig('../plots_and_pictures/model_knn_p1_n12_scatter.png', transparent=False)

# %%
mf.conf_matrix_as_bar_perc(knn_p1_n12_cmx)
plt.savefig('../plots_and_pictures/model_knn_p1_n12_barplot.png', transparent=False)
